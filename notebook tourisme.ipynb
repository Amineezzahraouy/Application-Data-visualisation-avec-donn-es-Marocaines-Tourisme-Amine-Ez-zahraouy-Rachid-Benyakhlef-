# %%
pip install bokeh
# Out:
# ...
#
# ...

# %%
import pandas as pd

# Charger les données
data = {
    'Année': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
    'Recettes en MDHs': [56421.5, 58904, 57835, 57614, 62034, 61150, 64226, 72127, 73039, 78654, 36364]
}

df = pd.DataFrame(data)

# Afficher les premières lignes du dataset
print("Aperçu des premières lignes du dataset :")
print(df.head())

# Afficher les informations sur le dataset
print("\nInformations sur le dataset :")
print(df.info())

# Vérifier s'il y a des valeurs manquantes
print("\nValeurs manquantes :")
print(df.isnull().sum())

# Afficher les statistiques descriptives du dataset
print("\nStatistiques descriptives du dataset :")
print(df.describe())

# Expliquer les raisons du choix de ce dataset
print("\nRaisons du choix de ce dataset :")
print("1. Pertinence : Ce dataset fournit des informations sur les recettes en devises d'un pays sur une période de plusieurs années, ce qui est pertinent pour analyser l'économie et les tendances financières.")
print("2. Disponibilité : Les données sont disponibles sur une plage temporelle significative, ce qui permet d'analyser les tendances à long terme.")
print("3. Complétude : Le dataset semble complet et ne contient pas de valeurs manquantes, ce qui facilite l'analyse.")
print("4. Intérêt personnel : Les recettes en devises sont un indicateur important de la santé économique d'un pays, ce qui rend ce dataset intéressant pour l'analyse et l'étude.")

# Vous pouvez ajouter d'autres analyses ou explications selon vos besoins

# Visualiser les données
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Année'], df['Recettes en MDHs'], marker='o', linestyle='-')
plt.title('Evolution des recettes en devises au Maroc (2010-2020)')
plt.xlabel('Année')
plt.ylabel('Recettes en MDHs')
plt.grid(True)
plt.show()
# Out:
# Aperçu des premières lignes du dataset :
#    Année  Recettes en MDHs
# 0   2010           56421.5
# 1   2011           58904.0
# 2   2012           57835.0
# 3   2013           57614.0
# 4   2014           62034.0
#
# Informations sur le dataset :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Année             11 non-null     int64
#  1   Recettes en MDHs  11 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 308.0 bytes
# None
#
# Valeurs manquantes :
# Année               0
# Recettes en MDHs    0
# dtype: int64
#
# Statistiques descriptives du dataset :
#              Année  Recettes en MDHs
# count    11.000000         11.000000
# mean   2015.000000      61669.863636
# std       3.316625      11138.872488
# min    2010.000000      36364.000000
# 25%    2012.500000      57724.500000
# ...

# %%
import pandas as pd

# Charger les données
data = {
    'provinces': ['T.AIR', 'A Marrakech Ménara', 'A Mohammed V', 'A Agadir Almassira', 'A Tanger Ibn Battouta', 
                  'A Fes-Saiss', 'A Rabat-Salé', 'A Laaroui', 'A Oujda', 'A Essaouira', 
                  'A Ouarzazate', 'A Al Hoceima', 'T.MER', 'P Tanger Med', 'P Tanger', 
                  'P Nador', 'T.TERRE', 'T Bab Sebta', 'T Béni Anzar'],
    '2012': [6018566, 1704466, 2072133, 620892, 520313, 308680, 165599, 335068, 201287, 14192, 20692, 33036, 
             1941411, 1283665, 453297, 173138, 1415179, 955716, 423511],
    '2013': [6691449, 1945749, 2244025, 672779, 552301, 373996, 216177, 329741, 242308, 41167, 18355, 25674, 
             1993108, 1255511, 497551, 202191, 1361707, 927826, 400409],
    '2014': [6949937, 2127712, 2287427, 677415, 504430, 379615, 328844, 296864, 246585, 32073, 18076, 20047, 
             2036256, 1287987, 504139, 195402, 1296751, 886907, 372393],
    '2015': [6772274, 2018946, 2195330, 653281, 514425, 418920, 330339, 298765, 240298, 33075, 16895, 21655, 
             2113132, 1306118, 496452, 200662, 1291356, 879517, 381192],
    '2016': [6803955, 1836803, 2302466, 618100, 569166, 410869, 408442, 318942, 235559, 34593, 13411, 19360, 
             2198274, 1387661, 478478, 216609, 1329502, 899747, 395602],
    '2017': [7619256, 2039428, 2469405, 739447, 711604, 492418, 420603, 343139, 270977, 43933, 16720, 28481, 
             2482494, 1425155, 594654, 349342, 1247594, 865097, 348348],
    '2018': [8399533, 2554542, 2545734, 864229, 692511, 541353, 428196, 335032, 287256, 52265, 21630, 29194, 
             2471635, 1371880, 659795, 312585, 1417540, 992323, 383462],
    '2019': [9081490, 3093694, 2527306, 874336, 697941, 574188, 462914, 354843, 291963, 60559, 45003, 36656, 
             2320959, 1258640, 670513, 315461, 1529811, 1049168, 435843],
    '2020': [2265090, 657343, 716387, 194983, 190007, 162607, 104383, 117353, 69484, 19236, 10054, 6143, 
             293270, 179745, 64774, 42625, 219442, 157483, 49863]
}

point_dentrée = pd.DataFrame(data)

# Afficher les premières lignes du point d'entrée
print("Aperçu des premières lignes du dataset des point d'entrée :")
print(point_dentrée.head())

# Afficher les informations sur le point d'entrée
print("\nInformations sur le dataset des point d'entrée :")
print(point_dentrée.info())

# Vérifier s'il y a des valeurs manquantes
print("\nValeurs manquantes :")
print(point_dentrée.isnull().sum())

# Afficher les statistiques descriptives du point d'entrée
print("\nStatistiques descriptives du dataset des point d'entrée :")
print(point_dentrée.describe())

# Expliquer les raisons du choix de ce dataset
print("\nRaisons du choix de ce dataset des point d'entrée :")
print("1. Pertinence : Ce dataset fournit des informations sur le transport touristique dans différentes provinces du Maroc sur une période de plusieurs années, ce qui est pertinent pour analyser les tendances touristiques.")
print("2. Variété : Le dataset comprend des données sur plusieurs provinces et plusieurs années, ce qui permet une analyse approfondie et comparative.")
print("3. Source de données fiable : Les données semblent être issues d'une source fiable, ce qui renforce leur crédibilité pour l'analyse.")

# Vous pouvez ajouter d'autres analyses ou explications selon vos besoins

# Visualiser les données
# Vous pouvez utiliser des visualisations appropriées comme des graphiques à barres, des diagrammes en boîte, etc.
# Out:
# Aperçu des premières lignes du dataset des point d'entrée :
#                provinces     2012     2013     2014     2015     2016  \
# 0                  T.AIR  6018566  6691449  6949937  6772274  6803955
# 1     A Marrakech Ménara  1704466  1945749  2127712  2018946  1836803
# 2           A Mohammed V  2072133  2244025  2287427  2195330  2302466
# 3     A Agadir Almassira   620892   672779   677415   653281   618100
# 4  A Tanger Ibn Battouta   520313   552301   504430   514425   569166
#
#       2017     2018     2019     2020
# 0  7619256  8399533  9081490  2265090
# 1  2039428  2554542  3093694   657343
# 2  2469405  2545734  2527306   716387
# 3   739447   864229   874336   194983
# 4   711604   692511   697941   190007
#
# Informations sur le dataset des point d'entrée :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Raisons du choix du dataset
raison = """
Raisons du choix du dataset :
- L'évolution par nationalité des arrivées des touristes est un indicateur clé pour comprendre les tendances du tourisme dans un pays.
- Ce dataset fournit des données détaillées sur les arrivées touristiques par nationalité pour les années 2012 à 2020, ce qui permet d'analyser les variations au fil du temps.
- Les données proviennent des postes frontières, ce qui en fait une source fiable pour évaluer l'impact des politiques touristiques et des événements mondiaux sur le tourisme au Maroc.
"""

# Données fournies
data = {
    'nationalite': ['France', 'Espagne', 'Royaume-Uni', 'Allemagne', 'Italie', 
                    'Etats Unis', 'Belgique', 'Hollande', 'Maghreb', 'Chine', 'Scandinavie', 'MRE'],
    '2012': [1769710, 730882, 357347, 199349, 196186, 140045, 255290, 204767, 219280, 6899, 67165, 4363427],
    '2013': [1782056, 682834, 403325, 237852, 234912, 160033, 272593, 210859, 270227, 7871, 83999, 4722931],
    '2014': [1798190, 683761, 476550, 255124, 254209, 167267, 267308, 191158, 213675, 9403, 95193, 4845491],
    '2015': [1563568, 626896, 504475, 286328, 227961, 181468, 243815, 183349, 195214, 10515, 83554, 5025058],
    '2016': [1449757, 615720, 458561, 260255, 219334, 197858, 238984, 182379, 209823, 42844, 93009, 5228527],
    '2017': [1614011, 710729, 486262, 331185, 246312, 254531, 259658, 214016, 207885, 107434, 118460, 5484427],
    '2018': [1844397, 814069, 510516, 394328, 305505, 304960, 273535, 237539, 214295, 132081, 136157, 5609607],
    '2019': [1990813, 880818, 551499, 413384, 351916, 346702, 272328, 241065, 227281, 141050, 104264, 5889254],
    '2020': [412179, 200136, 113258, 79077, 57105, 54103, 40603, 40909, 49240, 20529, 22119, 1369808]
}

# Création d'un DataFrame à partir des données
df = pd.DataFrame(data)

# Renommer le dataset en "arrivees_touristes_par_nationalite"
df = df.rename(columns={'nationalite': 'Nationalité'})

# Plot
plt.figure(figsize=(12, 8))
for column in df.columns[1:]:
    plt.bar(df['Nationalité'], df[column], label=column, alpha=0.7)

plt.title('Évolution par nationalité des arrivées des touristes aux postes frontières (2012-2020)')
plt.xlabel('Nationalité')
plt.ylabel('Nombre d\'arrivées')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(axis='y')

# Affichage des raisons du choix du dataset
plt.figtext(0.5, 0.01, raison, ha='center', fontsize=10, wrap=True, bbox=dict(facecolor='lightgrey', edgecolor='black', boxstyle='round,pad=1'))

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Données fournies
data = {
    'hotels': ['Hôtel 1*', 'Hôtel 2*', 'Hôtel 3*', 'Hôtel 4*', 'Hôtel 5*', 'Luxe', 
               'Résidences Hôtelières', 'Clubs Hôtels', 'Maisons d\'Hôtes', 'Autres*'],
    '2012': [13160, 14382, 28884, 41595, 28273, 4654, 14216, 18970, 20243, 15371],
    '2013': [14908, 14922, 29312, 43249, 28684, 4832, 15188, 19692, 22185, 19443],
    '2014': [15447, 15247, 30391, 44311, 28610, 4832, 17921, 19692, 23625, 22974],
    '2015': [15793, 16456, 30575, 45733, 30554, 5354, 19492, 19647, 26740, 24054],
    '2016': [16101, 16811, 31578, 47952, 32677, 5784, 21413, 20013, 28101, 25146],
    '2017': [16403, 16998, 32288, 49287, 34235, 6052, 22535, 20675, 29721, 26294],
    '2018': [16624, 17350, 33239, 50181, 34909, 6052, 24085, 20930, 30813, 27727],
    '2019': [16713, 17721, 34167, 51031, 36937, 6363, 24873, 20930, 31818, 28887],
    '2020': [16921, 18088, 34898, 51139, 37461, 6363, 25564, 20930, 32848, 30180]
}

# Création d'un DataFrame à partir des données
df_hotels = pd.DataFrame(data)

# Renommer le dataset en "capacite_hoteliere"
df_hotels = df_hotels.rename(columns={'hotels': 'Types d\'hôtels'})

# Affichage des statistiques descriptives
print("Statistiques descriptives de la capacité hôtelière classée en lits :")
print(df_hotels.describe())

# Visualisation de la capacité hôtelière classée en lits
plt.figure(figsize=(12, 8))
for column in df_hotels.columns[1:]:
    plt.plot(df_hotels['Types d\'hôtels'], df_hotels[column], label=column)

plt.title('Évolution de la capacité hôtelière classée en lits (2012-2020)')
plt.xlabel('Types d\'hôtels')
plt.ylabel('Capacité en lits')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Statistiques descriptives de la capacité hôtelière classée en lits :
#                2012          2013          2014          2015          2016  \
# count     10.000000     10.000000     10.000000     10.000000     10.000000
# mean   19974.800000  21241.500000  22305.000000  23439.800000  24557.600000
# std    10453.894254  10526.925437  10644.721697  10924.446996  11498.426812
# min     4654.000000   4832.000000   4832.000000   5354.000000   5784.000000
# 25%    14257.500000  14988.500000  16065.500000  17215.000000  17611.500000
# 50%    17170.500000  19567.500000  21333.000000  21850.500000  23279.500000
# 75%    26265.500000  27059.250000  27363.750000  29600.500000  30708.750000
# max    41595.000000  43249.000000  44311.000000  45733.000000  47952.000000
#
#                2017          2018          2019          2020
# count     10.000000     10.000000     10.000000     10.000000
# mean   25448.800000  26191.000000  26944.000000  27439.200000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Données fournies
capacite_data = {
    'provinces': ['Marrakech', 'Agadir-Taghazout', 'Casablanca', 'Tanger-Assilah', 'Fès', 'Ifrane', 
                  'Oujda-Saidia', 'Essaouira-Mogador', 'Ouarzazate', 'Rabat', 'Al Haouz', 'Meknès', 'El Jadida-Mazagan'],
    '2012': [56581, 34014, 14472, 8568, 7785, 6663, 7006, 5223, 6384, 5601, 3043, 3633, 2646],
    '2013': [59298, 34762, 14885, 9448, 8156, 8423, 7781, 5354, 6630, 5866, 3149, 3729, 2674],
    '2014': [60517, 37199, 15141, 10176, 9429, 8542, 7901, 5632, 6791, 5982, 3277, 4452, 2672],
    '2015': [64556, 37824, 15959, 10672, 9791, 8974, 7894, 5876, 6863, 5982, 5243, 4563, 2740],
    '2016': [67453, 38603, 18751, 11620, 10094, 9014, 7894, 6090, 6960, 6080, 5277, 4589, 2793],
    '2017': [69486, 38823, 18883, 12176, 10298, 9099, 9052, 6185, 7251, 6458, 5667, 4648, 2793],
    '2018': [71294, 38983, 20416, 12419, 10346, 9149, 9052, 6303, 7251, 6468, 5715, 4670, 2869],
    '2019': [73048, 40136, 21200, 13497, 10346, 9149, 9116, 6481, 7290, 6468, 5995, 4705, 2949],
    '2020': [73175, 40660, 21417, 14060, 10586, 9149, 9116, 8602, 7302, 6654, 5995, 4705, 2949]
}

# Création d'un DataFrame à partir des données
df_capacite = pd.DataFrame(capacite_data)

# Renommer le dataset en "capacite_hoteliere_destination"
df_capacite = df_capacite.rename(columns={'provinces': 'Destinations'})

# Affichage des statistiques descriptives
print("Statistiques descriptives de l'évolution de la capacité hôtelière classée en lits par destination :")
print(df_capacite.describe())

# Visualisation de l'évolution de la capacité hôtelière classée en lits par destination
plt.figure(figsize=(12, 8))
for column in df_capacite.columns[1:]:
    plt.plot(df_capacite['Destinations'], df_capacite[column], label=column)

plt.title('Évolution de la capacité hôtelière classée en lits par destination (2012-2020)')
plt.xlabel('Destinations')
plt.ylabel('Capacité en lits')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Statistiques descriptives de l'évolution de la capacité hôtelière classée en lits par destination :
#                2012          2013          2014          2015          2016  \
# count     13.000000     13.000000     13.000000     13.000000     13.000000
# mean   12432.230769  13088.846154  13670.076923  14379.769231  15016.769231
# std    15585.459383  16187.340928  16646.241715  17536.970796  18302.637402
# min     2646.000000   2674.000000   2672.000000   2740.000000   2793.000000
# 25%     5223.000000   5354.000000   5632.000000   5876.000000   6080.000000
# 50%     6663.000000   7781.000000   7901.000000   7894.000000   7894.000000
# 75%     8568.000000   9448.000000  10176.000000  10672.000000  11620.000000
# max    56581.000000  59298.000000  60517.000000  64556.000000  67453.000000
#
#                2017          2018          2019          2020
# count     13.000000     13.000000     13.000000     13.000000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Raisons du choix du dataset
raison = """
Raisons du choix du dataset :
- L'évolution par destination de la capacité hôtelière classée en lits est un indicateur important pour évaluer le développement du secteur touristique dans différentes régions.
- Ces données fournissent des informations détaillées sur la capacité hôtelière classée en lits pour diverses destinations touristiques au Maroc sur une période de plusieurs années (2012-2020).
- Analyser l'évolution de la capacité hôtelière par destination peut aider à identifier les tendances de voyage et à prendre des décisions stratégiques en matière de développement touristique.
"""

# Données fournies
capacite_data = {
    'provinces': ['Marrakech', 'Agadir-Taghazout', 'Casablanca', 'Tanger-Assilah', 'Fès', 'Ifrane', 
                  'Oujda-Saidia', 'Essaouira-Mogador', 'Ouarzazate', 'Rabat', 'Al Haouz', 'Meknès', 'El Jadida-Mazagan'],
    '2012': [56581, 34014, 14472, 8568, 7785, 6663, 7006, 5223, 6384, 5601, 3043, 3633, 2646],
    '2013': [59298, 34762, 14885, 9448, 8156, 8423, 7781, 5354, 6630, 5866, 3149, 3729, 2674],
    '2014': [60517, 37199, 15141, 10176, 9429, 8542, 7901, 5632, 6791, 5982, 3277, 4452, 2672],
    '2015': [64556, 37824, 15959, 10672, 9791, 8974, 7894, 5876, 6863, 5982, 5243, 4563, 2740],
    '2016': [67453, 38603, 18751, 11620, 10094, 9014, 7894, 6090, 6960, 6080, 5277, 4589, 2793],
    '2017': [69486, 38823, 18883, 12176, 10298, 9099, 9052, 6185, 7251, 6458, 5667, 4648, 2793],
    '2018': [71294, 38983, 20416, 12419, 10346, 9149, 9052, 6303, 7251, 6468, 5715, 4670, 2869],
    '2019': [73048, 40136, 21200, 13497, 10346, 9149, 9116, 6481, 7290, 6468, 5995, 4705, 2949],
    '2020': [73175, 40660, 21417, 14060, 10586, 9149, 9116, 8602, 7302, 6654, 5995, 4705, 2949]
}

# Création d'un DataFrame à partir des données
df_capacite = pd.DataFrame(capacite_data)

# Renommer le dataset en "capacite_hoteliere_par_destination"
df_capacite = df_capacite.rename(columns={'provinces': 'Destinations'})

# Plot
plt.figure(figsize=(12, 8))
for column in df_capacite.columns[1:]:
    plt.bar(df_capacite['Destinations'], df_capacite[column], label=column, alpha=0.7)

plt.title('Évolution par destination de la capacité hôtelière classée en lits (2012-2020)')
plt.xlabel('Destinations')
plt.ylabel('Capacité hôtelière classée en lits')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(axis='y')



plt.show()

# Affichage des raisons du choix du dataset
print(raison)
# Out:
# Raisons du choix du dataset :
# - L'évolution par destination de la capacité hôtelière classée en lits est un indicateur important pour évaluer le développement du secteur touristique dans différentes régions.
# - Ces données fournissent des informations détaillées sur la capacité hôtelière classée en lits pour diverses destinations touristiques au Maroc sur une période de plusieurs années (2012-2020).
# - Analyser l'évolution de la capacité hôtelière par destination peut aider à identifier les tendances de voyage et à prendre des décisions stratégiques en matière de développement touristique.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Raisons du choix du dataset
raison = """
Raisons du choix du dataset :
- L'évolution par nationalité des arrivées des touristes est un indicateur clé pour comprendre les tendances du tourisme dans un pays.
- Ce dataset fournit des données détaillées sur les arrivées touristiques par nationalité pour les années 2012 à 2020, ce qui permet d'analyser les variations au fil du temps.
- Les données proviennent des postes frontières, ce qui en fait une source fiable pour évaluer l'impact des politiques touristiques et des événements mondiaux sur le tourisme au Maroc.
"""

# Données fournies
data = {
    'nationalite': ['France', 'Espagne', 'Royaume-Uni', 'Allemagne', 'Italie', 
                    'Etats Unis', 'Belgique', 'Hollande', 'Maghreb', 'Chine', 'Scandinavie', 'MRE'],
    '2012': [1769710, 730882, 357347, 199349, 196186, 140045, 255290, 204767, 219280, 6899, 67165, 4363427],
    '2013': [1782056, 682834, 403325, 237852, 234912, 160033, 272593, 210859, 270227, 7871, 83999, 4722931],
    '2014': [1798190, 683761, 476550, 255124, 254209, 167267, 267308, 191158, 213675, 9403, 95193, 4845491],
    '2015': [1563568, 626896, 504475, 286328, 227961, 181468, 243815, 183349, 195214, 10515, 83554, 5025058],
    '2016': [1449757, 615720, 458561, 260255, 219334, 197858, 238984, 182379, 209823, 42844, 93009, 5228527],
    '2017': [1614011, 710729, 486262, 331185, 246312, 254531, 259658, 214016, 207885, 107434, 118460, 5484427],
    '2018': [1844397, 814069, 510516, 394328, 305505, 304960, 273535, 237539, 214295, 132081, 136157, 5609607],
    '2019': [1990813, 880818, 551499, 413384, 351916, 346702, 272328, 241065, 227281, 141050, 104264, 5889254],
    '2020': [412179, 200136, 113258, 79077, 57105, 54103, 40603, 40909, 49240, 20529, 22119, 1369808]
}

# Création d'un DataFrame à partir des données
df = pd.DataFrame(data)

# Renommer le dataset en "arrivees_touristes_par_nationalite"
df = df.rename(columns={'nationalite': 'Nationalité'})

# Plot
plt.figure(figsize=(12, 8))
for column in df.columns[1:]:
    plt.bar(df['Nationalité'], df[column], label=column, alpha=0.7)

plt.title('Évolution par nationalité des arrivées des touristes aux postes frontières (2012-2020)')
plt.xlabel('Nationalité')
plt.ylabel('Nombre d\'arrivées')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(axis='y')

# Affichage des raisons du choix du dataset
plt.figtext(0.5, 0.01, raison, ha='center', fontsize=10, wrap=True, bbox=dict(facecolor='lightgrey', edgecolor='black', boxstyle='round,pad=1'))

plt.show()
print(raison)
# Out:
# Raisons du choix du dataset :
# - L'évolution par nationalité des arrivées des touristes est un indicateur clé pour comprendre les tendances du tourisme dans un pays.
# - Ce dataset fournit des données détaillées sur les arrivées touristiques par nationalité pour les années 2012 à 2020, ce qui permet d'analyser les variations au fil du temps.
# - Les données proviennent des postes frontières, ce qui en fait une source fiable pour évaluer l'impact des politiques touristiques et des événements mondiaux sur le tourisme au Maroc.
